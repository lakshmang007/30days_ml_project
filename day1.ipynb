# %%
#Day 1: Simple Linear Regression – Predict calorie burn based on workout duration.

# %%
import numpy as np #linear algebra
import pandas as pd # data processing csv i/o

# %%
# %pip install matplotlib seaborn plotly -q
# Out:
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.0.1 -> 26.0.1
# [notice] To update, run: C:\Users\laksh\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from xgboost import XGBRegressor
from sklearn import metrics
from plotly.offline import init_notebook_mode, iplot  
init_notebook_mode(connected=True)
import warnings
warnings.filterwarnings('ignore')
# Out:
#         <script>
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         </script>
#         <script type="module">import "https://cdn.plot.ly/plotly-3.4.0.min"</script>

# %%
import sys
import os
import platform

print("=" * 50)
print("ENVIRONMENT INFORMATION")
print("=" * 50)
print(f"Python Version: {sys.version}")
print(f"Python Executable: {sys.executable}")
print(f"Platform: {platform.platform()}")
print(f"Processor: {platform.processor()}")
print(f"\nPython Path:")
for path in sys.path:
    print(f"  {path}")
print(f"\nCurrent Working Directory: {os.getcwd()}")
print("=" * 50)
# Out:
# ...
# ENVIRONMENT INFORMATION
# ...
# Python Version: 3.11.9 (tags/v3.11.9:de54cf5, Apr  2 2024, 10:12:12) [MSC v.1938 64 bit (AMD64)]
# Python Executable: C:\Users\laksh\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\python.exe
# Platform: Windows-10-10.0.26200-SP0
# Processor: AMD64 Family 25 Model 68 Stepping 1, AuthenticAMD
#
# Python Path:
#   C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.11_3.11.2544.0_x64__qbz5n2kfra8p0\python311.zip
#   C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.11_3.11.2544.0_x64__qbz5n2kfra8p0\DLLs
#   C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.11_3.11.2544.0_x64__qbz5n2kfra8p0\Lib
#   C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.11_3.11.2544.0_x64__qbz5n2kfra8p0
#
#   C:\Users\laksh\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages
# ...

# %%
# Load the data
import os
data_path = r'C:\30ml\30days_ml_project\mlp1'

# Load CSV files
exercise_df = pd.read_csv(os.path.join(data_path, 'exercise.csv'))
calories_df = pd.read_csv(os.path.join(data_path, 'calories.csv'))

print("Exercise Data:")
print(exercise_df.head())
print(f"\nShape: {exercise_df.shape}")
print("\n" + "="*50)
print("\nCalories Data:")
print(calories_df.head())
print(f"\nShape: {calories_df.shape}")
print("\n" + "="*50)
print("\nData Types:")
print("\nExercise Data Types:")
print(exercise_df.dtypes)
print("\nCalories Data Types:")
print(calories_df.dtypes)
# Out:
# Exercise Data:
#     User_ID  Gender  Age  Height  Weight  Duration  Heart_Rate  Body_Temp
# 0  14733363    male   68   190.0    94.0      29.0       105.0       40.8
# 1  14861698  female   20   166.0    60.0      14.0        94.0       40.3
# 2  11179863    male   69   179.0    79.0       5.0        88.0       38.7
# 3  16180408  female   34   179.0    71.0      13.0       100.0       40.5
# 4  17771927  female   27   154.0    58.0      10.0        81.0       39.8
#
# Shape: (15000, 8)
#
# ...
#
# Calories Data:
#     User_ID  Calories
# 0  14733363     231.0
# 1  14861698      66.0
# 2  11179863      26.0
# 3  16180408      71.0
# 4  17771927      35.0
#
# Shape: (15000, 2)
#
# ...
#
# Data Types:
#
# Exercise Data Types:
# User_ID         int64
# Gender         object
# Age             int64
# Height        float64
# Weight        float64
# Duration      float64
# Heart_Rate    float64
# Body_Temp     float64
# dtype: object
#
# Calories Data Types:
# User_ID       int64
# ...

# %%
calories = pd.read_csv('C:\30ml\30days_ml_project\mlp1\calories.csv')
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 calories = pd.read_csv('C:\30ml\30days_ml_project\mlp1\calories.csv')
#
# ...
